# %% [markdown]
# # View Dataset for Agents

# %%
import pandas as pd

# %%
trips_df = pd.read_csv('Tables_Data/trip_recommendations.csv')
tickets_df = pd.read_csv('Tables_Data/tickets.csv')
ticketsflight_df = pd.read_csv('Tables_Data/ticket_flights.csv')
seats_df = pd.read_csv('Tables_Data/seats.csv')
hotels_df = pd.read_csv('Tables_Data/hotels.csv')
flights_df = pd.read_csv('Tables_Data/flights.csv')
car_booking_df = pd.read_csv('Tables_Data/car_rental_bookings.csv')
car_df = pd.read_csv('Tables_Data/car_rentals.csv')
bookings_df = pd.read_csv('Tables_Data/bookings.csv')
boarding_df = pd.read_csv('Tables_Data/boarding_passes.csv')
airports_df = pd.read_csv('Tables_Data/airports_data.csv')
aircrafts_df = pd.read_csv('Tables_Data/aircrafts_data.csv')
passengers_df = pd.read_csv('Tables_Data/passengers.csv')
trip_booking_df = pd.read_csv('Tables_Data/trip_bookings.csv')
hotel_booking_df = pd.read_csv('Tables_Data/hotel_bookings.csv')

# %%
trips_df
# Out:
#     id                             name     location  \
# 0    1                    Chợ Bến Thành  Hồ Chí Minh
# 1    2  Bảo tàng Chứng tích Chiến tranh  Hồ Chí Minh
# 2    3                   Địa đạo Củ Chi  Hồ Chí Minh
# 3    4           Nhà thờ Đức Bà Sài Gòn  Hồ Chí Minh
# 4    5                  Chùa Ngọc Hoàng  Hồ Chí Minh
# ..  ..                              ...          ...
# 85  86                      Rừng U Minh       Cà Mau
# 86  87          Khu bảo tồn chim Cà Mau       Cà Mau
# 87  88     Tham quan trang trại mật ong       Cà Mau
# 88  89                          Chợ nổi       Cà Mau
# 89  90         Vườn quốc gia Mũi Cà Mau       Cà Mau
#
#                                         keywords  \
# 0         chợ,mua sắm,văn hóa địa phương,ẩm thực
# 1           lịch sử,chiến tranh,bảo tàng,văn hóa
# 2          lịch sử,địa đạo,chiến tranh,đường hầm
# 3          nhà thờ,kiến trúc,thực dân,danh thắng
# 4             chùa,tâm linh,văn hóa,truyền thống
# ..                                           ...
# 85   rừng,ngập mặn,hệ sinh thái,đa dạng sinh học
# 86            chim,bảo tồn,bảo tồn,đất ngập nước
# 87    mật ong,làm ruộng,sản phẩm địa phương,ngọt
# 88  chợ nổi,thuyền,thương mại địa phương,văn hóa
# 89            vườn quốc gia,mũi,ven biển,bảo tồn
#
#                                               details availability
# 0   Chợ trung tâm nổi tiếng với sản phẩm địa phươn...  unavailable
# 1   Bảo tàng lịch sử trưng bày các hiện vật và trư...    available
# 2   Mạng lưới đường hầm ngầm nổi tiếng được sử dụn...  unavailable
# 3       Nhà thờ thực dân Pháp đẹp trong tim thành phố    available
# 4   Chùa Đạo giáo cổ xưa dành riêng cho Ngọc Hoàng...    available
# ..                                                ...          ...
# 85  Hệ sinh thái rừng ngập mặn độc đáo với động vậ...    available
# 86  Khu bảo tồn đất ngập nước quan trọng bảo vệ ch...  unavailable
# 87  Tham quan trang trại mật ong địa phương và thư...    available
# 88  Chợ nổi truyền thống giới thiệu văn hóa thương...  unavailable
# 89  Vườn quốc gia ven biển bảo vệ hệ sinh thái cực...  unavailable
#
# [90 rows x 6 columns]
